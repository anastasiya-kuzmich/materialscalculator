# %% [markdown]
# # Materials Calculator: MVP

# %%
import pandas as pd
import numpy as np

### SPREADSHEET INPUT

path = input("Please insert the path to your csv file:")
costs = pd.read_csv(path)

### CLEANING

costs = costs.dropna(how='all', axis=1)
costs = costs.dropna(how='all', axis=0)

costs["Description"] = costs["Description"].fillna("")
costs['Item Name'] = costs['Item Name'].str.strip()

del costs["Unnamed: 24"]

new_costs = []
           
for cost_name, item_name, description, uom in zip(costs['Cost Name'], costs['Item Name'], costs["Description"], costs["UOM"]):
    
    # Renaming dyes for clarity on colour
    if cost_name == "Dye":
        new_costs.append(str(cost_name + " -" + item_name))
        
    # Replacing question marks with Item Names for Clarity
    elif "?" in cost_name:
        replacement = "for" + str(item_name)
        new_costs.append(cost_name.replace('?"', replacement))
        
    # Adding the material kind to YKK zips
    elif "YKK" in cost_name:
        new_costs.append(str(cost_name + " (" + description + ")"))
    
    # Adding the size to the Sublimation Dyes
    elif cost_name == "Sublimation Dye":
        new_costs.append(str(cost_name + " (" + uom + ")"))
    
    else:
        new_costs.append(cost_name)
    
costs["costs"] = new_costs

new_UOM = []

for uom in costs["UOM"]:
    if "A" in uom:
        new_UOM.append("pcs")
    else:
        new_UOM.append(uom)

costs["UOM"] = new_UOM

material_costs = costs[costs["Cost Label"] == "Materials"]

material_costs = material_costs.drop(["C-Code", "Cost Name", "I-Code", "Unit Cost", "Cost Label", "Cost Sublabel", "Description"], axis=1)

cost_per = []

for cost in material_costs["Cost Per"]:
    if "-" in cost:
        cost_per.append("0")
    elif "£" in cost:
        cost_per.append(cost.replace("£", ""))
    else:
        cost_per.append(cost)

cost_per = [float(i) for i in cost_per]
material_costs["Cost Per"] = cost_per

del new_costs, new_UOM, cost_per

material_costs = material_costs.rename(columns={"Yield": "Units", "Cost Per": "Cost Per Unit", "costs" : "Material"})

costs = pd.DataFrame(material_costs)

### USER INPUT - ORDER QUANTITY

item_names = {}

for item_name in costs["Item Name"].unique():
    item_names[item_name] = 0
    
for key, value in item_names.items():
    item_names[key] = int(input("How many " + key + "s?"))
    
### CALCULATIONS

costs['Quantity'] = costs['Item Name'].map(item_names)

material_costs = costs.copy()

del material_costs["Item Name"]

material_costs["Total Units"] = material_costs["Units"] * material_costs["Quantity"]

material_costs["Total Cost"] = material_costs["Total Units"] * material_costs["Cost Per Unit"]

material_costs[['Material', 'Total Units', 'UOM', 'Total Cost']]


### OUTPUT

print("Your Quantity Request:")

print("\n")

for key, value in item_names.items():
    print(str(value) + " " + str(key) + "s")
    
print("\n")

print("This order will cost you", round(material_costs["Total Cost"].sum(),2), "in total")
print("\n")
print("Your price breakdown is:")

output_costs = material_costs[['Material', 'Total Units', 'UOM', 'Total Cost']].groupby('Material', as_index=False).sum(numeric_only = True).round(2)

mat_and_uom = {}

for material, uom in zip(material_costs['Material'], material_costs['UOM']):
    if material not in mat_and_uom.keys():
        mat_and_uom[material] = uom

output_costs['Units of Measure'] = output_costs['Material'].map(mat_and_uom)
output_costs = output_costs[["Material", "Total Units", "Units of Measure", "Total Cost"]]

output_costs
# Out:
# Your Quantity Request:
# 1 Amir Puffer Jackets
# 1 Amir Cargo Pants
# 4 Zilla Skin Bonnets
# 0 Zilla Skin Tops
# 3 Ralien Hoodies
# 2 Ralien Pants
# 5 Ralien Glovess
# 1 S-Tops
# 1 S-Pants
# 1 S-Gilets
# 1 Karis Jackets
# 0 Karis Pants
# 1 Mum-Gilets
# 3 Elli-Mesh Shirts
# 2 Caedon Bags
# 3 M-Jackets
# 0 M-Pants
# 10 Ralien T-Shirts
# 1 Elli-Combat Hats
#
#
# This order will cost you 1123.76 in total
#
#
# Your price breakdown is:
#                               Material  Total Units Units of Measure  \
# 0         Atomic Blue Waterproof nylon          5.5                m
# 1                   Buckle 2-Part 40MM          4.0              pcs
# 2                            Camo Knit          0.5                m
# 3                         Clothing Tag         40.0              pcs
# 4                            DTG Print         20.0              pcs
# 5                      Deadstock Denim          3.0                m
# 6                 Dye -Amir Cargo Pant          2.0              pcs
# 7              Dye -Amir Puffer Jacket          2.0              pcs
# 8                 Dye -Elli-Mesh Shirt          0.9              pcs
# 9                    Dye -Karis Jacket          2.0              pcs
# 10                     Dye -Karis Pant          0.0              pcs
# 11                       Dye -M-Jacket          6.0              pcs
# 12                         Dye -M-Pant          0.0              pcs
# 13                  Dye -Ralien Hoodie          6.0              pcs
# 14                    Dye -Ralien Pant          4.0              pcs
# 15                        Elastic Cord          4.0              pcs
# 16                Elastic Webbing 25MM          0.5                m
# 17                Elastic Webbing 80MM          1.4                m
# 18                              Eyelet         14.0              pcs
# 19                  Heavyweight Jersey         10.5                m
# 20                     Laminated Scuba          2.0                m
# 21                        Nylon Lining          4.0                m
# 22                Red Waterproof Nylon          3.0                m
# 23                             Ribbing          2.5                m
# 24                       Ripstop Nylon          4.5                m
# 25                          Russel 215         10.0              pcs
# 26                               Scuba          2.5                m
# 27                       Snap fastener         12.0              pcs
# 28                         Sport Mesh           9.0                m
# 29                  Stretch Seersucker          0.8                m
# 30                Sublimation Dye (A2)          8.0              pcs
# 31                Sublimation Dye (A3)          3.0              pcs
# 32                Sublimation Dye (A4)         28.0              pcs
# 33                   Upcycled Garments         12.0              pcs
# 34                              Velcro          0.4                m
# 35                       Waste Bedding          3.5              pcs
# 36                    Waterproof Nylon          4.0                m
# 37           YKK 7" closed end (Metal)         10.0              pcs
# 38     YKK Closed-end Zip 30CM (Metal)          2.0              pcs
# 39   YKK Closed-end Zip 36CM (Plastic)          5.0              pcs
# 40     YKK Invisble Zip 10CM (Plastic)          2.0              pcs
# 41     YKK Invisble Zip 20CM (Plastic)          4.0              pcs
# 42        YKK Two-way Zip 65CM (Metal)          4.0              pcs
# 43      YKK Two-way Zip 76CM (Plastic)          1.0              pcs
# 44  YKK Waterproof Two-Way Zip (Metal)          3.0              pcs
# 45              YKK forS-Pant open end          2.0              pcs
#
#     Total Cost
# 0        55.00
# 1        12.00
# 2         2.00
# 3        60.00
# 4        75.00
# 5        39.00
# 6        16.00
# 7        16.00
# 8         7.20
# 9        16.00
# 10        0.00
# 11       48.00
# 12        0.00
# 13       48.00
# 14       32.00
# 15        5.04
# 16        0.50
# 17        2.80
# 18        1.40
# 19       94.50
# 20       60.00
# 21       16.00
# 22        0.00
# 23       17.38
# 24       22.50
# 25       60.00
# 26       12.50
# 27        1.56
# 28       27.00
# 29        8.00
# 30       60.00
# 31       12.00
# 32       36.00
# 33       84.00
# 34        1.04
# 35        0.00
# 36       70.00
# 37       20.00
# 38        4.00
# 39       10.00
# 40        3.00
# 41        8.00
# 42       24.00
# 43        2.35
# 44       30.00
# 45        4.00

# %%
# Out:
#                               Material  Total Units  Total Cost  \
# 0         Atomic Blue Waterproof nylon          5.5       55.00
# 1                   Buckle 2-Part 40MM          4.0       12.00
# 2                            Camo Knit          0.5        2.00
# 3                         Clothing Tag         40.0       60.00
# 4                            DTG Print         20.0       75.00
# 5                      Deadstock Denim          3.0       39.00
# 6                 Dye -Amir Cargo Pant          2.0       16.00
# 7              Dye -Amir Puffer Jacket          2.0       16.00
# 8                 Dye -Elli-Mesh Shirt          0.9        7.20
# 9                    Dye -Karis Jacket          2.0       16.00
# 10                     Dye -Karis Pant          0.0        0.00
# 11                       Dye -M-Jacket          6.0       48.00
# 12                         Dye -M-Pant          0.0        0.00
# 13                  Dye -Ralien Hoodie          6.0       48.00
# 14                    Dye -Ralien Pant          4.0       32.00
# 15                        Elastic Cord          4.0        5.04
# 16                Elastic Webbing 25MM          0.5        0.50
# 17                Elastic Webbing 80MM          1.4        2.80
# 18                              Eyelet         14.0        1.40
# 19                  Heavyweight Jersey         10.5       94.50
# 20                     Laminated Scuba          2.0       60.00
# 21                        Nylon Lining          4.0       16.00
# 22                Red Waterproof Nylon          3.0        0.00
# 23                             Ribbing          2.5       17.38
# 24                       Ripstop Nylon          4.5       22.50
# 25                          Russel 215         10.0       60.00
# 26                               Scuba          2.5       12.50
# 27                       Snap fastener         12.0        1.56
# 28                         Sport Mesh           9.0       27.00
# 29                  Stretch Seersucker          0.8        8.00
# 30                Sublimation Dye (A2)          8.0       60.00
# 31                Sublimation Dye (A3)          3.0       12.00
# 32                Sublimation Dye (A4)         28.0       36.00
# 33                   Upcycled Garments         12.0       84.00
# 34                              Velcro          0.4        1.04
# 35                       Waste Bedding          3.5        0.00
# 36                    Waterproof Nylon          4.0       70.00
# 37           YKK 7" closed end (Metal)         10.0       20.00
# 38     YKK Closed-end Zip 30CM (Metal)          2.0        4.00
# 39   YKK Closed-end Zip 36CM (Plastic)          5.0       10.00
# 40     YKK Invisble Zip 10CM (Plastic)          2.0        3.00
# 41     YKK Invisble Zip 20CM (Plastic)          4.0        8.00
# 42        YKK Two-way Zip 65CM (Metal)          4.0       24.00
# 43      YKK Two-way Zip 76CM (Plastic)          1.0        2.35
# 44  YKK Waterproof Two-Way Zip (Metal)          3.0       30.00
# 45              YKK forS-Pant open end          2.0        4.00
#
#    Units of Measure
# 0                 m
# 1               pcs
# 2                 m
# 3               pcs
# 4               pcs
# 5                 m
# 6               pcs
# 7               pcs
# 8               pcs
# 9               pcs
# 10              pcs
# 11              pcs
# 12              pcs
# 13              pcs
# 14              pcs
# 15              pcs
# 16                m
# 17                m
# 18              pcs
# 19                m
# 20                m
# 21                m
# 22                m
# 23                m
# 24                m
# 25              pcs
# 26                m
# 27              pcs
# 28                m
# 29                m
# 30              pcs
# 31              pcs
# 32              pcs
# 33              pcs
# 34                m
# 35              pcs
# 36                m
# 37              pcs
# 38              pcs
# 39              pcs
# 40              pcs
# 41              pcs
# 42              pcs
# 43              pcs
# 44              pcs
# 45              pcs
